# %%
# prompt: write complete code for a basic sentiment anayzer

# !pip install nltk

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

def analyze_sentiment(text):
  """Analyzes the sentiment of a given text using VADER.

  Args:
    text: The text to analyze.

  Returns:
    A dictionary containing the sentiment scores (positive, negative, neutral, compound).
  """
  analyzer = SentimentIntensityAnalyzer()
  scores = analyzer.polarity_scores(text)
  return scores
# Out:
# ...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
  text_to_analyze = "Today is a fine sunny day"
  sentiment_scores = analyze_sentiment(text_to_analyze)

  print(f"Sentiment Scores for: '{text_to_analyze}'")
  print(f"Positive: {sentiment_scores['pos']:.2f}")
  print(f"Negative: {sentiment_scores['neg']:.2f}")
  print(f"Neutral: {sentiment_scores['neu']:.2f}")
  print(f"Compound: {sentiment_scores['compound']:.2f}")
# Out:
# Sentiment Scores for: 'Today is a fine sunny day'
# Positive: 0.60
# Negative: 0.00
# Neutral: 0.40
# Compound: 0.56
